# %% [markdown]
# <a href="https://colab.research.google.com/github/taisazero/langchain-crashcourse/blob/main/notebooks/3-retrieval_aug_gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lab Activity 2: Retrieval Augmented Generation

# %%
# !pip install -q lancedb
# Out:
# WARNING: Ignoring invalid distribution -hainlit (c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages)
# WARNING: Ignoring invalid distribution -hainlit (c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages)

# %%
import lancedb
from langchain.vectorstores import LanceDB
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import LanceDB
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
# !pip install --upgrade gdown
# Out:
# Requirement already satisfied: gdown in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (4.7.1)
# Collecting gdown
#   Obtaining dependency information for gdown from https://files.pythonhosted.org/packages/cb/56/f4845ed78723a4eb8eb22bcfcb46e1157a462c78c0a5ed318c68c98f9a79/gdown-5.1.0-py3-none-any.whl.metadata
#   Downloading gdown-5.1.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from gdown) (3.12.4)
# Requirement already satisfied: requests[socks] in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from requests[socks]->gdown) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from requests[socks]->gdown) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages (from tqdm->gdown) (0.4.6)
# Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.7.1
#     Uninstalling gdown-4.7.1:
#       Successfully uninstalled gdown-4.7.1
# Successfully installed gdown-5.1.0
# WARNING: Ignoring invalid distribution -hainlit (c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages)
# WARNING: Ignoring invalid distribution -hainlit (c:\users\erfan\miniconda3\envs\langcourse\lib\site-packages)

# %%
import gdown
gdown.download_folder(
    "https://drive.google.com/drive/folders/1SkI0ttpMNTVHp6ear6cTLDooRmtqvmVo?usp=sharing",
      # quiet=True,
      output="./") 

# gdown.download_folder(
#         "https://drive.google.com/drive/folders/" +
#         "1ZXEhzbLRLU1giKKRJkjm8N04cO_JoYE2",
#     )
# Out:
# Retrieving folder contents
# Retrieving folder 125v7crzZdl1f-9odUAkBlt3zjcye3Byz hf_docs.lance
# Processing file 1DDfAhEkT54w1nCEW1NhSRn1HL6DptQ79 _latest.manifest
# Retrieving folder 18xRZzn2tXosaxWjngxv68wDHzDQlL9-c _transactions
# Processing file 1emNCD4lfJilhhP0pVkvCMCiIe9lmPw2d 0-44251552-057e-4436-a333-5fe8f5fa7811.txn
# Processing file 1QiIAX8NtigddOkVAHNqGiZK3XRjudm17 1-4a9bd1c8-8975-4f86-9d2c-20892e9d60eb.txn
# Processing file 17LKhR0-PmPIW9muYDvF9fw08IE4bRNTH 2-5a5fe9bc-55e5-4131-ade6-7db3b1a24a67.txn
# Retrieving folder 1SfZhJWDqmtzHpl_DhWLBTQQX_rcGX_ht _versions
# Processing file 1dyejR7hRUlufFp2JvtOPyzOu6QdvSlSl 1.manifest
# Processing file 1Cs8SLBS0rvvgL2d9Ty3gA59eGBGslw1h 2.manifest
# Processing file 1OCH7z4GK4OOVdXXJmAlV6pa0PqWjvqCP 3.manifest
# Retrieving folder 1g3tfW9ImMQKivva3vRIp8BSChSDLA7xs data
# Processing file 1TJ_gdl0ZN5d75hSe675Gf0DGyIU90oa6 b1bfbe40-a8a4-4831-8b52-376b3ed4e4d7.lance
# Processing file 1UuaU4gqxRiUo4on3C801eh_QUYbtMLVI c56f7736-b405-4e84-92bd-dae34990f417.lance
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1DDfAhEkT54w1nCEW1NhSRn1HL6DptQ79
# To: c:\Users\erfan\Documents\projects\langchain-crashcourse\notebooks\.answer_keys\hf_docs.lance\_latest.manifest
# 100%|██████████| 307/307 [00:00<?, ?B/s]
# Downloading...
# From: https://drive.google.com/uc?id=1emNCD4lfJilhhP0pVkvCMCiIe9lmPw2d
# To: c:\Users\erfan\Documents\projects\langchain-crashcourse\notebooks\.answer_keys\hf_docs.lance\_transactions\0-44251552-057e-4436-a333-5fe8f5fa7811.txn
# 100%|██████████| 158/158 [00:00<00:00, 158kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QiIAX8NtigddOkVAHNqGiZK3XRjudm17
# To: c:\Users\erfan\Documents\projects\langchain-crashcourse\notebooks\.answer_keys\hf_docs.lance\_transactions\1-4a9bd1c8-8975-4f86-9d2c-20892e9d60eb.txn
# 100%|██████████| 96.0/96.0 [00:00<00:00, 106kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=17LKhR0-PmPIW9muYDvF9fw08IE4bRNTH
# To: c:\Users\erfan\Documents\projects\langchain-crashcourse\notebooks\.answer_keys\hf_docs.lance\_transactions\2-5a5fe9bc-55e5-4131-ade6-7db3b1a24a67.txn
# 100%|██████████| 96.0/96.0 [00:00<00:00, 96.0kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1dyejR7hRUlufFp2JvtOPyzOu6QdvSlSl
# To: c:\Users\erfan\Documents\projects\langchain-crashcourse\notebooks\.answer_keys\hf_docs.lance\_versions\1.manifest
# 100%|██████████| 197/197 [00:00<00:00, 131kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Cs8SLBS0rvvgL2d9Ty3gA59eGBGslw1h
# To: c:\Users\erfan\Documents\projects\langchain-crashcourse\notebooks\.answer_keys\hf_docs.lance\_versions\2.manifest
# 100%|██████████| 250/250 [00:00<?, ?B/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OCH7z4GK4OOVdXXJmAlV6pa0PqWjvqCP
# To: c:\Users\erfan\Documents\projects\langchain-crashcourse\notebooks\.answer_keys\hf_docs.lance\_versions\3.manifest
# 100%|██████████| 307/307 [00:00<?, ?B/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TJ_gdl0ZN5d75hSe675Gf0DGyIU90oa6
# To: c:\Users\erfan\Documents\projects\langchain-crashcourse\notebooks\.answer_keys\hf_docs.lance\data\b1bfbe40-a8a4-4831-8b52-376b3ed4e4d7.lance
# 100%|██████████| 6.39k/6.39k [00:00<00:00, 6.40MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1UuaU4gqxRiUo4on3C801eh_QUYbtMLVI
# To: c:\Users\erfan\Documents\projects\langchain-crashcourse\notebooks\.answer_keys\hf_docs.lance\data\c56f7736-b405-4e84-92bd-dae34990f417.lance
# 100%|██████████| 45.5M/45.5M [00:02<00:00, 17.5MB/s]
# Download completed
# ['./hf_docs.lance\\_latest.manifest',
#  './hf_docs.lance\\_transactions\\0-44251552-057e-4436-a333-5fe8f5fa7811.txn',
#  './hf_docs.lance\\_transactions\\1-4a9bd1c8-8975-4f86-9d2c-20892e9d60eb.txn',
#  './hf_docs.lance\\_transactions\\2-5a5fe9bc-55e5-4131-ade6-7db3b1a24a67.txn',
#  './hf_docs.lance\\_versions\\1.manifest',
#  './hf_docs.lance\\_versions\\2.manifest',
#  './hf_docs.lance\\_versions\\3.manifest',
#  './hf_docs.lance\\data\\b1bfbe40-a8a4-4831-8b52-376b3ed4e4d7.lance',
#  './hf_docs.lance\\data\\c56f7736-b405-4e84-92bd-dae34990f417.lance']

# %%
db = lancedb.connect('../.lancedb_hf')
table = db.open_table('hf_docs')
from langchain.embeddings import HuggingFaceEmbeddings
from transformers import AutoModel
# TODO: Create an OpenAIEmbeddings object and a LanceDB vectorstore instantiated with the table and OpenAIEmbeddings.
# embedding_fn = OpenAIEmbeddings(chunk_size=200)

model = AutoModel.from_pretrained('jinaai/jina-embeddings-v2-small-en', trust_remote_code=True)
    
embedding_fn = HuggingFaceEmbeddings(model_name= "jinaai/jina-embeddings-v2-small-en", model_kwargs = {'device': 'cpu'})  # rate limit
vectorstore = LanceDB(table, embedding_fn)

# %% [markdown]
# ## Experiment: Retrieval-Augmented Generation
#
# TODO: Write a python snippet that creates an llm using the ChatOpenAI object with a temperature of 0, and prompt it with the question:
#
# > "Can you describe PEFT from the transformers library?"
#
# Store this question in a variable called `query`.
#
# Then, print the output of the llm.

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.llms import OpenAI
#TODO: Create a RetrievalQA object with the ChatOpenAI model, the vectorstore's retriever, and a chain_type of "stuff".
qa = RetrievalQA.from_chain_type(
    llm=ChatOpenAI(temperature=0, model='gpt-3.5-turbo-16k')
    , chain_type="stuff", retriever=vectorstore.as_retriever(search_kwargs=dict(k=5)),
      verbose=True, return_source_documents = True)

# %%
# TODO: Ask a question about the transformers library.
query = "Can you describe PEFT from the transformers library?"
answer = qa({"query": query})
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.

# %%
answer
# Out:
# {'query': 'Can you describe PEFT from the transformers library?',
#  'result': "I'm sorry, but I don't have information about PEFT in the transformers library.",
#  'source_documents': [Document(page_content='https://huggingface.co/docs/datasets/about_cache\nThe fingerprint of a dataset is updated by hashing the function passed to map\nas well as the map parameters (batch_size, remove_columns, etc.). You can\ncheck the hash of any Python object using the fingerprint.Hasher: Copied >>>\nfrom datasets.fingerprint import Hasher >>> my_func = lambda example:\n{"length": len(example["text"])} >>> print(Hasher.hash(my_func))\n\'3d35e2b3e94c81d6\' The hash is computed by dumping the object using a dill\npickler and hashing the dumped bytes. The pickler recursively dumps all the\nvariables used in your function, so any change you do to an object that is\nused in your function, will cause the hash to change. If one of your functions\ndoesn’t seem to have the same hash across sessions, it means at least one of\nits variables contains a Python object that is not deterministic. When this\nhappens, feel free to hash any object you find suspicious to try to find the\nobject that caused the hash to change. For example, if you use a list for\nwhich the order of its elements is not deterministic across sessions, then the\nhash won’t be the same across sessions either. ←Datasets 🤝 Arrow Dataset or\nIterableDataset→ The cache Fingerprint Hashing', metadata={'vector': array([-1.81706131e-01, -2.14498639e-01,  3.84513289e-01,  4.70136672e-01,
#           8.39089379e-02, -5.86494990e-02,  2.58827984e-01,  3.61049980e-01,
#          -1.01289414e-02, -1.07524492e-01,  2.33494014e-01,  2.78222650e-01,
#          -2.37032384e-01, -4.77800488e-01,  3.18041235e-01, -3.49142462e-01,
#          -3.12798694e-02, -2.44684383e-01, -1.53402500e-02,  3.03911492e-02,
#          -1.63842723e-01, -3.71444434e-01, -2.80150861e-01,  9.65363681e-02,
#           2.06383109e-01, -8.78790021e-02, -2.84052908e-01,  7.40634277e-02,
#           1.82903305e-01, -1.28375605e-01,  4.60345984e-01,  2.15608567e-01,
#           3.77599537e-01,  2.43740126e-01, -3.77381265e-01, -3.58778924e-01,
#           1.15364157e-01,  4.76067215e-01,  2.25247234e-01, -5.89481182e-02,
#           3.93773198e-01,  2.78557271e-01, -2.73459870e-02,  2.92772770e-01,
#          -2.07662299e-01, -5.35738111e-01, -2.09610686e-01, -4.71357286e-01,
#          -3.05761069e-01, -7.95713365e-02, -1.32354289e-01,  2.41077349e-01,
#           3.79788518e-01,  4.81018335e-01, -3.05902570e-01, -2.99205065e-01,
#          -1.69278130e-01, -4.96352911e-01,  1.40101880e-01,  1.19684152e-01,
#           1.17371500e-01, -2.01812178e-01,  1.65885881e-01,  3.46296504e-02,
#           2.62225837e-01, -1.39741212e-01,  2.81291693e-01,  2.95502663e-01,
#           9.63786766e-02,  2.70373017e-01,  1.53744847e-01, -1.60243779e-01,
#          -5.60340524e-01,  1.90842837e-01,  2.85970598e-01,  2.43630470e-03],
#         dtype=float32), 'id': 'ba72990f-9a31-42e5-8372-90beffa38cd4', '_distance': 42.945037841796875}),
#   Document(page_content='https://huggingface.co/docs/datasets/about_cache\nThe cache Hugging Face Models Datasets Spaces Docs Solutions Pricing Log In\nSign Up Datasets documentation The cache Datasets Search documentation\nmainv2.14.5v2.13.2v2.12.0v2.11.0v2.10.0v2.9.0v2.8.0v2.7.1v2.6.2v2.5.2v2.4.0v2.3.2v2.2.1v2.1.0v2.0.0v1.18.3v1.17.0v1.16.1v1.15.1v1.14.0v1.13.3v1.12.1v1.11.0v1.10.2v1.9.0v1.8.0v1.7.0v1.6.2v1.5.0v1.4.1v1.3.0v1.2.1v1.1.3v1.0.2v0.4.0v0.3.0\nEN Get started 🤗 Datasets Quickstart Installation Tutorials Overview Load a\ndataset from the Hub Know your dataset Preprocess Evaluate predictions Create\na dataset Share a dataset to the Hub How-to guides Overview General usage Load\nProcess Stream Use with TensorFlow Use with PyTorch Use with JAX Use with\nSpark Cache management Cloud storage Search index Metrics Beam Datasets Audio\nLoad audio data Process audio data Create an audio dataset Vision Load image\ndata Process image data Create an image dataset Depth estimation Image\nclassification Semantic segmentation Object detection Text Load text data\nProcess text data Tabular Load tabular data Dataset repository Share Create a\ndataset card Structure your repository Create a dataset loading script\nConceptual guides Datasets 🤝 Arrow The cache Dataset or IterableDataset\nDataset features Build and load Batch mapping All about metrics Reference Main\nclasses Builder classes Loading methods Table Classes Logging methods Task\ntemplates Join the Hugging Face community and get access to the augmented\ndocumentation experience Collaborate on models, datasets and Spaces Faster\nexamples with accelerated inference Switch between documentation themes Sign\nUp to get started The cache The cache is one of the reasons why 🤗 Datasets is\nso efficient. It stores previously downloaded and processed datasets so when\nyou need to use them again, they are reloaded directly from the cache. This\navoids having to download a dataset all over again, or reapplying processing\nfunctions. Even after you close and start another Python session, 🤗 Datasets\nwill reload your dataset directly from the cache! Fingerprint How does the\ncache keeps track of what transforms are applied to a dataset? Well, 🤗\nDatasets assigns a fingerprint to the cache file. A fingerprint keeps track of\nthe current state of a dataset. The initial fingerprint is computed using a\nhash from the Arrow table, or a hash of the Arrow files if the dataset is on\ndisk. Subsequent fingerprints are computed by combining the fingerprint of the\nprevious state, and a hash of the latest transform applied. Transforms are any\nof the processing methods from the How-to Process guides such as Dataset.map()\nor Dataset.shuffle(). Here are what the actual fingerprints look like: Copied\n>>> from datasets import Dataset >>> dataset1 = Dataset.from_dict({"a": [0, 1,\n2]}) >>> dataset2 = dataset1.map(lambda x: {"a": x["a"] + 1}) >>>\nprint(dataset1._fingerprint, dataset2._fingerprint) d19493523d95e2dc\n5b86abacd4b42434 In order for a transform to be hashable, it needs to be\npicklable by dill or pickle. When you use a non-hashable transform, 🤗 Datasets\nuses a random fingerprint instead and raises a warning. The non-hashable\ntransform is considered different from the previous transforms. As a result, 🤗\nDatasets will recompute all the transforms. Make sure your transforms are\nserializable with pickle or dill to avoid this! An example of when 🤗 Datasets\nrecomputes everything is when caching is disabled. When this happens, the\ncache files are generated every time and they get written to a temporary\ndirectory. Once your Python session ends, the cache files in the temporary\ndirectory are deleted. A random hash is assigned to these cache files, instead\nof a fingerprint. When caching is disabled, use Dataset.save_to_disk() to save\nyour transformed dataset or it will be deleted once the session ends. Hashing\nThe fingerprint of a dataset is updated by hashing the function passed to map\nas ...
#          -0.03867842,  0.09919645,  0.2912061 , -0.0998495 , -0.0490594 ,
#           0.17586108,  0.1080954 , -0.10978978, -0.3126323 ,  0.23643193,
#          -0.26425785,  0.02510541, -0.39762574, -0.25728735, -0.22563078,
#          -0.2696627 , -0.07204596, -0.02348255, -0.08721782,  0.16993317,
#          -0.25097016, -0.08998923,  0.08495748,  0.384278  ,  0.31720003,
#          -0.31003433,  0.06718675,  0.09022875,  0.0787115 , -0.14691894,
#           0.14164895,  0.03656939, -0.02164545, -0.20033354, -0.254416  ,
#          -0.07287275,  0.110047  ,  0.39376596,  0.17020325, -0.43786472,
#          -0.25483444, -0.31778055,  0.23015854,  0.12607542, -0.04743069,
#          -0.2958115 ,  0.10216863, -0.46612984,  0.14111547, -0.08134446,
#           0.11732081, -0.12066269,  0.33908236, -0.1788735 ,  0.1721108 ,
#           0.2726289 ,  0.17731087, -0.21445417,  0.17543854, -0.0590515 ,
#          -0.21644041, -0.13562137, -0.08891368, -0.1354387 ,  0.13869527,
#          -0.42822728,  0.07547302,  0.3545124 , -0.21489595,  0.19880208,
#           0.1127617 ,  0.03340209,  0.33693692, -0.00627579, -0.30258524,
#          -0.41301456, -0.02487774, -0.1512031 ,  0.10100442,  0.04082616,
#          -0.17296581,  0.09263027,  0.15119995,  0.42983478, -0.20238213,
#           0.09117768,  0.2604214 , -0.03840994, -0.56998765, -0.02344446,
#          -0.13184102,  0.33361247,  0.21988891, -0.31793514,  0.29893813,
#           0.4613409 ,  0.23925194,  0.15052354, -0.13926373, -0.05944105,
#           0.22612277,  0.04211256], dtype=float32), 'id': '2990d2c4-2ce6-4382-ae13-26214a42512e', '_distance': 43.024993896484375}),
#   Document(page_content="https://huggingface.co/docs/datasets/about_dataset_features\nDataset features Hugging Face Models Datasets Spaces Docs Solutions Pricing\nLog In Sign Up Datasets documentation Dataset features Datasets Search\ndocumentation\nmainv2.14.5v2.13.2v2.12.0v2.11.0v2.10.0v2.9.0v2.8.0v2.7.1v2.6.2v2.5.2v2.4.0v2.3.2v2.2.1v2.1.0v2.0.0v1.18.3v1.17.0v1.16.1v1.15.1v1.14.0v1.13.3v1.12.1v1.11.0v1.10.2v1.9.0v1.8.0v1.7.0v1.6.2v1.5.0v1.4.1v1.3.0v1.2.1v1.1.3v1.0.2v0.4.0v0.3.0\nEN Get started 🤗 Datasets Quickstart Installation Tutorials Overview Load a\ndataset from the Hub Know your dataset Preprocess Evaluate predictions Create\na dataset Share a dataset to the Hub How-to guides Overview General usage Load\nProcess Stream Use with TensorFlow Use with PyTorch Use with JAX Use with\nSpark Cache management Cloud storage Search index Metrics Beam Datasets Audio\nLoad audio data Process audio data Create an audio dataset Vision Load image\ndata Process image data Create an image dataset Depth estimation Image\nclassification Semantic segmentation Object detection Text Load text data\nProcess text data Tabular Load tabular data Dataset repository Share Create a\ndataset card Structure your repository Create a dataset loading script\nConceptual guides Datasets 🤝 Arrow The cache Dataset or IterableDataset\nDataset features Build and load Batch mapping All about metrics Reference Main\nclasses Builder classes Loading methods Table Classes Logging methods Task\ntemplates Join the Hugging Face community and get access to the augmented\ndocumentation experience Collaborate on models, datasets and Spaces Faster\nexamples with accelerated inference Switch between documentation themes Sign\nUp to get started Dataset features Features defines the internal structure of\na dataset. It is used to specify the underlying serialization format. What’s\nmore interesting to you though is that Features contains high-level\ninformation about everything from the column names and types, to the\nClassLabel. You can think of Features as the backbone of a dataset. The\nFeatures format is simple: dict[column_name, column_type]. It is a dictionary\nof column name and column type pairs. The column type provides a wide range of\noptions for describing the type of data you have. Let’s have a look at the\nfeatures of the MRPC dataset from the GLUE benchmark: Copied >>> from datasets\nimport load_dataset >>> dataset = load_dataset('glue', 'mrpc', split='train')\n>>> dataset.features {'idx': Value(dtype='int32', id=None), 'label':\nClassLabel(num_classes=2, names=['not_equivalent', 'equivalent'],\nnames_file=None, id=None), 'sentence1': Value(dtype='string', id=None),\n'sentence2': Value(dtype='string', id=None), } The Value feature tells 🤗\nDatasets: The idx data type is int32. The sentence1 and sentence2 data types\nare string. 🤗 Datasets supports many other data types such as bool, float32\nand binary to name just a few. Refer to Value for a full list of supported\ndata types. The ClassLabel feature informs 🤗 Datasets the label column\ncontains two classes. The classes are labeled not_equivalent and equivalent.\nLabels are stored as integers in the dataset. When you retrieve the labels,\nClassLabel.int2str() and ClassLabel.str2int() carries out the conversion from\ninteger value to label name, and vice versa. If your data type contains a list\nof objects, then you want to use the Sequence feature. Remember the SQuAD\ndataset? Copied >>> from datasets import load_dataset >>> dataset =\nload_dataset('squad', split='train') >>> dataset.features {'answers':\nSequence(feature={'text': Value(dtype='string', id=None), 'answer_start':\nValue(dtype='int32', id=None)}, length=-1, id=None), 'context':\nValue(dtype='string', id=None), 'id': Value(dtype='string', id=None),\n'question': Value(dtype='string', id=None), 'title': Value(dtype='string',\nid=None)} The answers field is constructed using the Sequence feature because\nit contains two subfields, text and answer_st ...
#           2.71956980e-01,  9.95138958e-02,  2.09258825e-01, -1.85844287e-01,
#           3.06580991e-01,  1.67298794e-01, -4.74934056e-02, -6.94446117e-02,
#          -1.24057591e-01,  1.52834907e-01,  3.98739353e-02,  8.72170106e-02,
#           3.34945798e-01, -4.10456091e-01,  6.37840703e-02, -7.37261549e-02,
#           5.47036529e-01, -2.94772774e-01,  2.72647709e-01,  6.22301623e-02,
#           1.69210076e-01,  4.14337605e-01,  2.05988199e-01, -1.88029572e-01,
#          -1.72487602e-01,  2.29024380e-01,  7.00923204e-02,  6.31367639e-02,
#          -1.58155873e-01, -3.31759900e-02, -1.12584293e-01, -2.77578700e-02,
#          -9.15334895e-02, -3.82979453e-01,  4.07447852e-02,  1.26784176e-01,
#           2.53767490e-01, -2.96162888e-02, -4.19762194e-01,  1.26219466e-01,
#           1.63658783e-01, -1.37867868e-01,  4.81844366e-01,  1.75786614e-01,
#           1.68185592e-01,  2.28069559e-01, -2.54572272e-01, -4.16143507e-01,
#           5.09118177e-02,  3.11574757e-01,  3.18892568e-01,  2.88971160e-02,
#           2.02545658e-01,  1.24251097e-01, -1.16223507e-01,  2.71689177e-01,
#          -2.54499704e-01, -1.70840323e-01, -1.61794633e-01, -3.67062271e-01,
#          -2.72469401e-01,  3.64223570e-02, -1.54211119e-01,  1.23124242e-01,
#           3.04534614e-01,  1.46353737e-01, -2.25898460e-01, -2.39503160e-01,
#          -3.84011455e-02, -2.07618684e-01,  1.60034120e-01,  1.74167410e-01,
#           1.49806485e-01, -1.98686600e-01,  2.40824699e-01,  2.25459322e-01,
#           2.33193442e-01, -1.63677335e-01,  8.98426399e-02,  1.53216884e-01,
#          -7.02337027e-02,  1.34452760e-01,  9.16593522e-02, -2.05823049e-01,
#          -3.31321210e-01,  1.22056723e-01,  1.78414598e-01,  7.04561174e-02],
#         dtype=float32), 'id': '179eff1d-83c4-4986-b20d-c993594845c3', '_distance': 43.691776275634766}),
#   Document(page_content='https://huggingface.co/docs/datasets/about_dataset_features\nit contains two subfields, text and answer_start, which are lists of string\nand int32, respectively. See the flatten section to learn how you can extract\nthe nested subfields as their own independent columns. The array feature type\nis useful for creating arrays of various sizes. You can create arrays with two\ndimensions using Array2D, and even arrays with five dimensions using Array5D.\nCopied >>> features = Features({\'a\': Array2D(shape=(1, 3), dtype=\'int32\')})\nThe array type also allows the first dimension of the array to be dynamic.\nThis is useful for handling sequences with variable lengths such as sentences,\nwithout having to pad or truncate the input to a uniform shape. Copied >>>\nfeatures = Features({\'a\': Array3D(shape=(None, 5, 2), dtype=\'int32\')}) Audio\nfeature Audio datasets have a column with type Audio, which contains three\nimportant fields: array: the decoded audio data represented as a 1-dimensional\narray. path: the path to the downloaded audio file. sampling_rate: the\nsampling rate of the audio data. When you load an audio dataset and call the\naudio column, the Audio feature automatically decodes and resamples the audio\nfile: Copied >>> from datasets import load_dataset, Audio >>> dataset =\nload_dataset("PolyAI/minds14", "en-US", split="train") >>> dataset[0]["audio"]\n{\'array\': array([ 0. , 0.00024414, -0.00024414, ..., -0.00024414, 0\\. , 0. ],\ndtype=float32), \'path\':\n\'/root/.cache/huggingface/datasets/downloads/extracted/f14948e0e84be638dd7943ac36518a4cf3324e8b7aa331c5ab11541518e9368c/en-\nUS~JOINT_ACCOUNT/602ba55abb1e6d0fbce92065.wav\', \'sampling_rate\': 8000} Index\ninto an audio dataset using the row index first and then the audio column -\ndataset[0]["audio"] - to avoid decoding and resampling all the audio files in\nthe dataset. Otherwise, this can be a slow and time-consuming process if you\nhave a large dataset. With decode=False, the Audio type simply gives you the\npath or the bytes of the audio file, without decoding it into an array, Copied\n>>> dataset = load_dataset("PolyAI/minds14", "en-US",\nsplit="train").cast_column("audio", Audio(decode=False)) >>> dataset[0]\n{\'audio\': {\'bytes\': None, \'path\':\n\'/root/.cache/huggingface/datasets/downloads/extracted/f14948e0e84be638dd7943ac36518a4cf3324e8b7aa331c5ab11541518e9368c/en-\nUS~JOINT_ACCOUNT/602ba55abb1e6d0fbce92065.wav\'}, \'english_transcription\': \'I\nwould like to set up a joint account with my partner\', \'intent_class\': 11,\n\'lang_id\': 4, \'path\':\n\'/root/.cache/huggingface/datasets/downloads/extracted/f14948e0e84be638dd7943ac36518a4cf3324e8b7aa331c5ab11541518e9368c/en-\nUS~JOINT_ACCOUNT/602ba55abb1e6d0fbce92065.wav\', \'transcription\': \'I would like\nto set up a joint account with my partner\'} Image feature Image datasets have\na column with type Image, which loads PIL.Image objects from images stored as\nbytes: When you load an image dataset and call the image column, the Image\nfeature automatically decodes the image file: Copied >>> from datasets import\nload_dataset, Image >>> dataset = load_dataset("beans", split="train") >>>\ndataset[0]["image"]  Index into an image dataset using the row index first and\nthen the image column - dataset[0]["image"] - to avoid decoding all the image\nfiles in the dataset. Otherwise, this can be a slow and time-consuming process\nif you have a large dataset. With decode=False, the Image type simply gives\nyou the path or the bytes of the image file, without decoding it into an\nPIL.Image, Copied >>> dataset = load_dataset("beans",\nsplit="train").cast_column("image", Image(decode=False)) >>>\ndataset[0]["image"] {\'bytes\': None, \'path\':\n\'/Users/username/.cache/huggingface/datasets/downloads/extracted/772e7c1fba622cff102b85dd74bcce46e8168634df4eaade7bedd3b8d91d3cd7/train/healthy/healthy_train.265.jpg\'}\nDepending on the dataset, you may get the path to the local downloade ...
#          -0.18400571,  0.14288971,  0.01940243,  0.06056253,  0.01216427,
#           0.12654334,  0.13189396, -0.08964361, -0.18681727,  0.15384302,
#          -0.29216522,  0.12152082, -0.44580954, -0.11292074, -0.31910896,
#          -0.18710706, -0.1669584 ,  0.0427837 , -0.01175258,  0.37838325,
#          -0.26626807, -0.06863448,  0.1147722 ,  0.13911083,  0.26958346,
#          -0.21528198,  0.15825967, -0.05641406,  0.00681048, -0.35845003,
#           0.06739609,  0.11802148, -0.01723404, -0.11551836, -0.29828298,
#          -0.06312574,  0.09543733,  0.20254835,  0.07714213, -0.22517146,
#          -0.22208509, -0.29796776,  0.3001031 ,  0.15670165, -0.01772675,
#          -0.22800045,  0.1622731 , -0.34803012,  0.20392755, -0.1353879 ,
#           0.2173026 , -0.00076757,  0.33819914, -0.20563467, -0.00276081,
#          -0.06407602,  0.48283434,  0.09420481,  0.24424496,  0.24483903,
#          -0.20635684, -0.35186228,  0.02064257,  0.25611863,  0.32179913,
#           0.02010701,  0.1940984 ,  0.2763372 , -0.14286256,  0.29241863,
#          -0.24893437, -0.32439488, -0.11343109, -0.31053853, -0.30163643,
#           0.06613614, -0.25188097,  0.13312659,  0.31604582,  0.28063023,
#          -0.2772333 , -0.31318647,  0.00436123, -0.23140848,  0.21597534,
#           0.3025124 ,  0.09422018, -0.19152556,  0.3540111 ,  0.16984534,
#           0.23288545, -0.28489855,  0.08959758,  0.22718409, -0.0823734 ,
#           0.15093644,  0.1144731 , -0.09457814, -0.3187192 ,  0.11604038,
#           0.23297359,  0.10380735], dtype=float32), 'id': '1eaf3a1d-1a10-4439-bbdb-425bcd58bf65', '_distance': 43.98284149169922}),
#   Document(page_content='https://huggingface.co/docs/datasets/about_arrow\nDatasets 🤝 Arrow Hugging Face Models Datasets Spaces Docs Solutions Pricing\nLog In Sign Up Datasets documentation Datasets 🤝 Arrow Datasets Search\ndocumentation\nmainv2.14.5v2.13.2v2.12.0v2.11.0v2.10.0v2.9.0v2.8.0v2.7.1v2.6.2v2.5.2v2.4.0v2.3.2v2.2.1v2.1.0v2.0.0v1.18.3v1.17.0v1.16.1v1.15.1v1.14.0v1.13.3v1.12.1v1.11.0v1.10.2v1.9.0v1.8.0v1.7.0v1.6.2v1.5.0v1.4.1v1.3.0v1.2.1v1.1.3v1.0.2v0.4.0v0.3.0\nEN Get started 🤗 Datasets Quickstart Installation Tutorials Overview Load a\ndataset from the Hub Know your dataset Preprocess Evaluate predictions Create\na dataset Share a dataset to the Hub How-to guides Overview General usage Load\nProcess Stream Use with TensorFlow Use with PyTorch Use with JAX Use with\nSpark Cache management Cloud storage Search index Metrics Beam Datasets Audio\nLoad audio data Process audio data Create an audio dataset Vision Load image\ndata Process image data Create an image dataset Depth estimation Image\nclassification Semantic segmentation Object detection Text Load text data\nProcess text data Tabular Load tabular data Dataset repository Share Create a\ndataset card Structure your repository Create a dataset loading script\nConceptual guides Datasets 🤝 Arrow The cache Dataset or IterableDataset\nDataset features Build and load Batch mapping All about metrics Reference Main\nclasses Builder classes Loading methods Table Classes Logging methods Task\ntemplates Join the Hugging Face community and get access to the augmented\ndocumentation experience Collaborate on models, datasets and Spaces Faster\nexamples with accelerated inference Switch between documentation themes Sign\nUp to get started Datasets 🤝 Arrow What is Arrow? Arrow enables large amounts\nof data to be processed and moved quickly. It is a specific data format that\nstores data in a columnar memory layout. This provides several significant\nadvantages: Arrow’s standard format allows zero-copy reads which removes\nvirtually all serialization overhead. Arrow is language-agnostic so it\nsupports different programming languages. Arrow is column-oriented so it is\nfaster at querying and processing slices or columns of data. Arrow allows for\ncopy-free hand-offs to standard machine learning tools such as NumPy, Pandas,\nPyTorch, and TensorFlow. Arrow supports many, possibly nested, column types.\nMemory-mapping 🤗 Datasets uses Arrow for its local caching system. It allows\ndatasets to be backed by an on-disk cache, which is memory-mapped for fast\nlookup. This architecture allows for large datasets to be used on machines\nwith relatively small device memory. For example, loading the full English\nWikipedia dataset only takes a few MB of RAM: Copied >>> import os; import\npsutil; import timeit >>> from datasets import load_dataset #\nProcess.memory_info is expressed in bytes, so convert to megabytes >>>\nmem_before = psutil.Process(os.getpid()).memory_info().rss / (1024 * 1024) >>>\nwiki = load_dataset("wikipedia", "20220301.en", split="train") >>> mem_after =\npsutil.Process(os.getpid()).memory_info().rss / (1024 * 1024) >>> print(f"RAM\nmemory used: {(mem_after - mem_before)} MB") RAM memory used: 50 MB This is\npossible because the Arrow data is actually memory-mapped from disk, and not\nloaded in memory. Memory-mapping allows access to data on disk, and leverages\nvirtual memory capabilities for fast lookups. Performance Iterating over a\nmemory-mapped dataset using Arrow is fast. Iterating over Wikipedia on a\nlaptop gives you speeds of 1-3 Gbit/s: Copied >>> s = """batch_size = 1000 ...\nfor batch in wiki.iter(batch_size): ... ... ... """ >>> time =\ntimeit.timeit(stmt=s, number=1, globals=globals()) >>> print(f"Time to iterate\nover the {wiki.dataset_size >> 30} GB dataset: {time:.1f} sec, " ... f"ie.\n{float(wiki.dataset_size >> 27)/time:.1f} Gb/s") Time to iterate over the 18\nGB dataset: 31.8 sec, ie. 4.8 Gb/s ←Create a dataset loading script The cache→\nDatasets 🤝  ...
#           4.70159799e-02, -1.06639594e-01,  1.13594480e-01,  2.38055840e-01,
#          -7.53369406e-02,  4.60205860e-02,  1.41122118e-01,  3.19539383e-02,
#          -1.13430299e-01, -3.70010138e-01,  1.73201188e-01, -2.22500756e-01,
#           1.15722723e-01, -4.15894985e-01, -1.66664481e-01, -3.16306233e-01,
#          -1.61929175e-01,  6.45492673e-02,  1.94061119e-02, -1.72538757e-01,
#           1.65917203e-01, -3.17209899e-01, -2.92613879e-02,  1.35645732e-01,
#           3.39287311e-01,  3.38973880e-01, -3.36080343e-01,  1.54089451e-01,
#          -1.60470739e-01,  1.60309002e-01, -2.07967252e-01,  7.53128156e-02,
#           6.27526119e-02, -1.69641431e-02, -1.05131112e-01, -2.21051812e-01,
#          -2.03657791e-01, -1.69500504e-02,  3.97804409e-01,  2.07532048e-01,
#          -3.73218179e-01, -4.38439138e-02, -4.95928586e-01,  3.14333051e-01,
#           2.93338932e-02,  7.05484822e-02, -2.58123964e-01,  1.35066852e-01,
#          -3.99777651e-01,  3.24699700e-01, -7.95848742e-02,  1.85922369e-01,
#          -1.35703355e-01,  3.54339927e-01, -2.04840213e-01,  4.32385914e-02,
#           1.27826586e-01,  1.75348356e-01, -1.76882342e-01,  4.45086136e-02,
#          -2.04201996e-01, -2.31246039e-01, -4.47269566e-02, -1.08263709e-01,
#          -1.06820934e-01,  9.39925238e-02, -4.14881140e-01, -1.23407394e-01,
#           2.91886806e-01, -2.95947194e-01,  1.42115816e-01,  8.50095823e-02,
#           2.96400767e-02,  2.27362916e-01,  6.73053935e-02, -3.06840658e-01,
#          -2.88025677e-01,  3.43355313e-02, -2.80407697e-01,  1.48398429e-01,
#          -1.23672999e-01, -2.34138444e-01,  2.67740577e-01, -2.89211422e-03,
# TODO: Write a python snippet that creates an llm using the ChatOpenAI object with a temperature of 0, and prompt it with `query`. Then, print the output of the llm. `query` is a string that contains the query you want to prompt the llm with and it should ask the language model a question related to the Huggingface library.

# %%
# TODO: Write your code here.
llm=ChatOpenAI(temperature=0, model='gpt-3.5-turbo-16k')
print(llm.predict(query))

# %% [markdown]
# ## Observations and Insights
# Write your observations and insights here. What do you think about the quality and correctness of the generated text from the two experiments?

# %% [markdown]
# ## More Prompts
# Now try querying the vanilla llm and the `RetrievalQA` chain with different questions related to the [**Huggingface** libraries](https://huggingface.co/docs/transformers/index). What do you observe? You are given two prompts below to try out first. Add your own prompts in new cells and try them out.

# %%
query = "Can you give me a crash course on using the HF Trainer to train a GPT-style model?"
answer = qa({"query": query})
print(answer['result'])

# %%
query = "Can you give me a crash course on using the HF Trainer to train a GPT-style model? Provide code snippets for each step."
answer = qa({"query": query})
print(answer['result'])

# %%
query = "Can you give me a crash course on using the HF Trainer to train a GPT-style model?"
print(llm.predict(query))

# %%
"Can you give me a crash course on using the HF Trainer to train a GPT-style model? Provide code snippets for each step."
print(llm.predict(query))

# %% [markdown]
# ## Increasing the Temperature

# %%
llm=ChatOpenAI(temperature=0.8, model='gpt-3.5-turbo-16k')
qa = RetrievalQA.from_chain_type(
    llm=llm, chain_type="stuff", retriever=vectorstore.as_retriever(search_kwargs=dict(k=5)),
      verbose=True, return_source_documents = True)

# %%
#TODO: Add your queries/questions here.
query = "Can you give me a crash course on using the HF Trainer to train a GPT-style model? Provide code snippets for each step."
answer = qa({"query": query})
print(answer['result'])
llm.predict(query)

# %% [markdown]
# Now try querying the vanilla llm and the `RetrievalQA` chain with the same questions after we increased the temperature. What do you notice?

# %%
#TODO: Add the queries here.

# %% [markdown]
# ## Observations and Insights
# Write your observations and insights here.
# Food for thought:
# * What was the impact of the instruction/prompt on the quality of the generated text?
# * What did you observe when increasing the temperature of the llm in the retrieval-augmented generation setting?
# * What do you think are the advantages and disadvantages of using retrieval-augmented generation?

# %% [markdown]
# ## Using Internet Search Engines to Augment Retrieval
#
# Hypothesis: This will be more useful than the previous method for questions that require a lot of background knowledge from multiple sources, such as "what is the best way to train a language model?", "how do I ... do in HF" and "crash course" requests. This approach will allow us to retrieve more relevant documents from the internet and cite them in our answer.

# %%
# !pip install -q google-api-python-client
# !pip install -q chromadb

# %% [markdown]
# ## Setup
#
# 1. To create an API key: Go to https://console.cloud.google.com/welcome/new and sign in/up using your personal Google account.
#    - Navigate to the APIs & Services→Credentials panel in Cloud Console.
#    - Select Create credentials, then select API key from the drop-down menu.
#    - The API key created dialog box displays your newly created key.
#    - You now have an API_KEY. Store in it in your `.env` file as `GOOGLE_API_KEY`.
#
# 2. Setup Custom Search Engine so you can search the entire web
#    - Create a custom search engine in this [link](http://www.google.com/cse/).
#    -  In Sites to search, select search the entire web. Select also enable SafeSearch and fill in your search engine name (it can be anything).
#    - Click on customize.
#    - Under Search engine ID you’ll find the search-engine-ID. Copy that and add it to your `.env` file as `GOOGLE_CSE_ID`.
#
# 3. Enable the Custom Search API
#    - Go to this [URL](https://console.cloud.google.com/apis/library/customsearch.googleapis.com) & click on Enable.
#    - Alternatively, navigate to the APIs & Services→Dashboard panel in Cloud Console.
#    - Click Enable APIs and Services.
#    - Search for Custom Search API and click on it.
#    - Click Enable.
#
# **Note**: Adapted from [GoogleSearchAPIWrapper Docs](https://api.python.langchain.com/en/latest/utilities/langchain.utilities.google_search.GoogleSearchAPIWrapper.html)

# %%
#TODO: Re-load the environment variables again
_ = load_dotenv(find_dotenv())

# %%
from langchain.retrievers.web_research import WebResearchRetriever
from langchain.vectorstores import Chroma
from langchain.utilities import GoogleSearchAPIWrapper
from langchain.embeddings import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI

# Vectorstore
vectorstore = Chroma(embedding_function=OpenAIEmbeddings(), persist_directory="./chromadb_oai")

# LLM
llm = ChatOpenAI(temperature=0, model='gpt-3.5-turbo-16k', max_tokens=512)

search = GoogleSearchAPIWrapper()

# %%
# Initialize
web_research_retriever = WebResearchRetriever.from_llm(
    vectorstore=vectorstore,
    llm=llm, 
    search=search,
    
)

# %%
from langchain.chains import RetrievalQAWithSourcesChain
query = "How can I finetune a Llama2 7b model on Google Colab?"
qa_chain = RetrievalQAWithSourcesChain.from_chain_type(llm, retriever=web_research_retriever)
result = qa_chain({"question": query})
result

# %%
from langchain.chains import RetrievalQAWithSourcesChain
query = "What are some recent news articles about OpenAI?"
qa_chain = RetrievalQAWithSourcesChain.from_chain_type(llm, retriever=web_research_retriever)
result = qa_chain({"question": query})
result

# %% [markdown]
# TODO for Erfan: Try adapting from https://blog.langchain.dev/building-chat-langchain-2/ to increase robustness. Can then do a VSCode Extension.

# %% [markdown]
# ## Observations and Insights
# Write any observations here.
# Food for thought:
# * Compare and contrast this approach with the previous huggingface question answering chain. What are the limitations of each approach? Can the previous approach search the entire web? Can this approach generate precise answers?
# * If we want to be able to retrieve more relevant documents from the internet but also generate complete answers to the user's question without having the user to read the retrieved documents. What are somethings we can do to make this approach do so?

# %%
# %%writefile ret_aug_app.py
from chainlit.config import config
import chainlit as cl
from langchain.memory import ConversationBufferMemory
from langchain.agents import AgentExecutor
from langchain.agents.initialize import initialize_agent
from langchain.agents import load_tools
from chainlit import on_message, on_chat_start
from langchain.chat_models import ChatOpenAI
from langchain.agents import AgentType
from langchain.tools import Tool
import lancedb
from langchain.vectorstores import LanceDB
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import LanceDB
from langchain.chains import RetrievalQA


#TODO: load environment variables from your .env file
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

@cl.on_chat_start
async def start():
    # TODO: initialize LLM (we use ChatOpenAI because we'll later define a `chat` agent), 
    # Hint: How can you enable live generation of the agent's messages?
    # BEGIN Writing
    llm = ChatOpenAI(
        temperature= 0,
        model_name='gpt-3.5-turbo-16k',
        max_tokens= 750,
        streaming=True
    )
    #TODO: create a memory, load tools, and initialize an agent with the type `CHAT_CONVERSATIONAL_REACT_DESCRIPTION`
    # Tip: Set `return_messages` to `True` in the memory so that the agent returns the messages it generates
    conversational_memory = ConversationBufferMemory(
        llm=llm,
        input_key='input',
        memory_key='chat_history',
        max_token_limit=250,
        return_messages=True,
    )
    #TODO: load the following tools ['llm-math', 'terminal', 'python_repl', 'serpapi']
    tools = load_tools(['llm-math', 'terminal', 'python_repl', 'serpapi'], llm=llm)
    #TODO: connect to `.lancedb` and open the `hf_docs` table, then create a LanceDB vectorstore with the table 
    # and the OpenAIEmbeddings object with chunk_size 200.
    db = lancedb.connect('.lancedb')
    table = db.open_table('hf_docs')
    embedding_fn = OpenAIEmbeddings(chunk_size=200)
    vectorstore = LanceDB(table, embedding_fn)
    #TODO: initialize your retrievalQA chain using the LanceDB `vectorstore` and the `llm` you initialized above
    # pass in chain_type of "stuff", and retrieve the top 5 documents.
    qa = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff", retriever=vectorstore.as_retriever(search_kwargs=dict(k=5)),
        verbose=True
    )
    # TODO: Create a tool that uses the `qa` chain we just initialized
    # Hint: Use the Tool.from_function method
    hf_docs_qa_tool = Tool.from_function(
        qa.run, name="huggingface documentation search",
        description="Use when you need to search the Hugging Face documentation for an answer to a question."
    )
    # We add the tool to the tools list
    tools.append(hf_docs_qa_tool)
    #TODO: initialize agent
    # Hint: There is a parameter that allows you to set the maximum number of iterations, 
        # this is useful to limit the number of messages the agent generates and hence $ spent on OAI credits.
    # Hint: CHAT_CONVERSATIONAL_REACT_DESCRIPTION needs the memory to return its messages.
    # Hint: How could you enable the agent to adapt to parsing issues it encounters?
    agent = initialize_agent(
        llm=llm,
        memory=conversational_memory,
        tools=tools,
        verbose=True,
        agent=AgentType.CHAT_CONVERSATIONAL_REACT_DESCRIPTION, 
        handle_parsing_errors=True,
        max_iterations=3,
    )
    
    # END Writing
    # create agentexecutor
    cl.user_session.set("agent", agent)

@cl.on_message
async def on_message(message):
    agent = cl.user_session.get("agent")
    response = await cl.make_async(agent.run)(
        input=message, callbacks=[cl.LangchainCallbackHandler()]
    )
    await cl.Message(content=response).send()

# %% [markdown]
# Now, let's serve the chainlit web interface with our agent. Run the cell below to start the chainlit web interface. You should see a link to the web interface. Click on the link to open the web interface in a new tab.

# %%
# Note if this cell says the port is already in use, you can change the port number to something else e.g. 8001 and so on.
# !chainlit run ret_aug_app.py --port 8001

# %% [markdown]
# ## Colab Setup
# If you are using Colab do not run the cell above, instead run this cell below. It will output a link and an ip-address. Use the link to access your chainlit UI application. It will first prompt you to enter the ip-address, enter the ip-address and click on connect. You should now be able to see the chainlit UI.

# %%
# !npm install localtunnel
# !chainlit run /content/ret_aug_app.py &>/content/logs.txt & npx localtunnel --port 8000 & curl ipv4.icanhazip.com

# %% [markdown]
# ## Additional Tasks
# If you finish early, you can try to complete the following tasks:
# * Insert a prompt to the RetrievalQAChain that instructs the model to formulate search engine optimal questions given the user query. Use the generated questions to query the search engine and retrieve documents. Try different prompts and instructions.
# * Add your best RetrievalQAChain to your agent as a tool from the last lab activity. Hint: Look into defining custom tools [langchain documentation](https://python.langchain.com/docs/modules/agents/tools/custom_tools).
# * Re-run the experiments with Llama2, compare and contrast the outputs based on correctness, helpfulness and conciseness.

# %% [markdown]
# ## References
# * https://lancedb.github.io/lancedb/notebooks/code_qa_bot/
# * https://github.com/langchain-ai/chat-langchain/tree/master
